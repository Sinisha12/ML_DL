# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
df_mkd = pd.read_csv('corona_north_macedonia.csv')

# %%
df_china = pd.read_csv('corona_china.csv')

# %%
data = np.array(df_china['active'])

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(data.reshape(-1,1))

# %%
scaled_full_data.shape
# Out:
# (65, 1)

# %%
length = 14
batch_size = 1
n_features = 1

# %%
generator = TimeseriesGenerator(scaled_full_data,scaled_full_data, length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(100 , activation='relu', input_shape=[length,n_features]))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator, epochs=20)
# Out:
# Epoch 1/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.0599
# Epoch 2/20
# 51/51 [==============================] - 2s 36ms/step - loss: 0.0303
# Epoch 3/20
# 51/51 [==============================] - 2s 35ms/step - loss: 0.0251
# Epoch 4/20
# 51/51 [==============================] - 2s 41ms/step - loss: 0.0123
# Epoch 5/20
# 51/51 [==============================] - 2s 37ms/step - loss: 0.0103
# Epoch 6/20
# 51/51 [==============================] - 2s 38ms/step - loss: 0.0086
# Epoch 7/20
# 51/51 [==============================] - 2s 40ms/step - loss: 0.0048
# Epoch 8/20
# 51/51 [==============================] - 3s 51ms/step - loss: 0.0066
# Epoch 9/20
# 51/51 [==============================] - 2s 46ms/step - loss: 0.0043
# Epoch 10/20
# 51/51 [==============================] - 2s 42ms/step - loss: 0.0037
# Epoch 11/20
# 51/51 [==============================] - 2s 42ms/step - loss: 0.0029
# Epoch 12/20
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0035
# Epoch 13/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.0030
# Epoch 14/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.0031
# Epoch 15/20
# 51/51 [==============================] - 3s 49ms/step - loss: 0.0022
# Epoch 16/20
# 51/51 [==============================] - 2s 43ms/step - loss: 0.0037
# Epoch 17/20
# 51/51 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 18/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.0020
# Epoch 19/20
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0027
# Epoch 20/20
# 51/51 [==============================] - 2s 41ms/step - loss: 0.0020

# %%
test_predictions = []
periods = 65
#first_eval_batch = scaled_train[-length:]
first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1,length,n_features))

for i in range(periods):
    current_predict = model.predict(current_batch)[0]
    test_predictions.append(current_predict)
    current_batch = np.append(current_batch[:,1:,:],[[current_predict]] ,axis = 1)

# %%
forecast_predictions = full_scaler.inverse_transform(test_predictions)

# %%
plt.figure(figsize=(20,10))
plt.plot(forecast_predictions, label = 'Active prediction')
plt.plot(df_china['active'], label = 'Active real')
plt.legend(fontsize=15)

# %%
scaled_full_data_mkd = full_scaler.fit_transform(np.array(df_mkd['active']).reshape(-1,1))

# %%
scaled_full_data_mkd.shape
# Out:
# (31, 1)

# %%
test_predictions = []
periods = 65
first_eval_batch = scaled_full_data_mkd[:length]
#first_eval_batch = scaled_full_data_mkd[-length:]
current_batch = first_eval_batch.reshape((1,length,n_features))

for i in range(periods):
    current_predict = model.predict(current_batch)[0]
    test_predictions.append(current_predict)
    current_batch = np.append(current_batch[:,1:,:],[[current_predict]] ,axis = 1)

# %%
forecast_predictions_mkd = full_scaler.inverse_transform(test_predictions)

# %%
plt.figure(figsize=(20,10))
plt.plot(forecast_predictions_mkd, label = 'Active prediction')
